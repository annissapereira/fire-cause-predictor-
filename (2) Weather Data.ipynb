# %% [markdown]
# ## 🌦 NOAA Daily Weather Dataset Description
#
# The NOAA (National Oceanic and Atmospheric Administration) daily weather dataset contains historical weather observations collected from multiple weather stations across California. These observations are recorded on a daily basis and include a wide range of meteorological variables.
#
# ### 🧾 Key Features:
# | Column     | Description |
# |------------|-------------|
# | `STATION`  | Unique station ID from NOAA’s GHCN database |
# | `NAME`     | Name of the weather station |
# | `LATITUDE` | Latitude of the weather station |
# | `LONGITUDE`| Longitude of the weather station |
# | `ELEVATION`| Elevation of the station (meters) |
# | `DATE`     | Date of the observation |
# | `AWND`     | Average wind speed (tenths of meters per second) |
# | `PGTM`     | Peak gust time (HHMM) |
# | `PRCP`     | Precipitation (tenths of mm) |
# | `TMAX`     | Maximum daily temperature (tenths of °C) |
# | `TMIN`     | Minimum daily temperature (tenths of °C) |
# | `WDF2`     | Direction of fastest 2-minute wind (degrees) |
# | `WDF5`     | Direction of fastest 5-second wind (degrees) |
# | `WSF2`     | Speed of fastest 2-minute wind (tenths of m/s) |
# | `WSF5`     | Speed of fastest 5-second wind (tenths of m/s) |
#
# ---
#
# ## 🔥 Importance of NOAA Weather Data in Predicting Wildfire Cause
#
# Weather conditions are among the most critical environmental factors influencing wildfire **ignition**, **spread**, and **severity**. Including NOAA weather data allows us to contextualize the wildfire with respect to its surrounding climate conditions, which can be strongly correlated with the cause.
#
# ### ✅ Why it Matters:
# - **High wind speeds** can indicate natural causes like **lightning-induced wildfires** or contribute to human-initiated spread.
# - **High temperatures** and **low precipitation** create dry environments, increasing flammability of vegetation.
# - **Weather direction/speed** helps assess whether fire spread was influenced by natural conditions.
#
# By aligning wildfire ignition records with historical weather conditions, we can improve the accuracy of classification models that predict the **cause of fire** (e.g., human vs. natural causes).
#
# ---
#
# ## 🎯 Purpose of Using NOAA Dataset
#
# 1. **Feature Engineering:** Create environment-based predictors (e.g., max temp, wind speed, rainfall levels).
# 2. **Modeling Fire Cause:** Use weather context to classify wildfire causes using supervised learning.
# 3. **Spatial-Temporal Enrichment:** Merge weather and fire records by location/date to model ignition conditions.
# 4. **Understanding Correlation:** Analyze how environmental variables contribute to specific fire causes.
#
# ---
# 📚 **Source:**
# This dataset is obtained from NOAA’s **Global Historical Climatology Network (GHCN)**. You can access the data [here](https://www.ncdc.noaa.gov/cdo-web/).
#
# > 🔄 The NOAA dataset enhances the temporal and environmental granularity of wildfire data, leading to more **explainable**, **reliable**, and **data-driven** predictions of fire causes.

# %% [markdown]
# # Data Exploration: Handling Missing Values
#
# ## 1. Identifying Missing Values
#
# In this step, we explore the dataset for missing values. We inspect the number of missing values in each column. Here’s an overview of the missing values count for each column in our dataset:

# %%
import pandas as pd

# Define the file path
file_path = r"C:\Users\annis\OneDrive\Desktop\California Wildfire\Data Files\3996332.csv"

# Load the CSV file into a DataFrame
weather_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to confirm it's loaded correctly
print(weather_df.head())
# Out:
#        STATION                                  NAME  LATITUDE  LONGITUDE  \
# 0  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
# 1  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
# 2  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
# 3  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
# 4  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
#
#    ELEVATION      DATE   ACMH   ACSH  AWND  DAPR  ...  WT11  WT13  WT14  WT16  \
# 0      101.9  1/1/1992   40.0    0.0  3.80   NaN  ...   NaN   NaN   NaN   NaN
# 1      101.9  1/2/1992  100.0  100.0  4.70   NaN  ...   NaN   NaN   NaN   NaN
# 2      101.9  1/3/1992  100.0  100.0  3.80   NaN  ...   NaN   NaN   NaN   1.0
# 3      101.9  1/4/1992   90.0   80.0  8.72   NaN  ...   NaN   NaN   NaN   NaN
# 4      101.9  1/5/1992  100.0  100.0  8.50   NaN  ...   NaN   NaN   NaN   1.0
#
#    WT18  WT21  WT22  WV01  WV03  WV20
# 0   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 50 columns]

# %%
weather_df.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'ACMH',
#        'ACSH', 'AWND', 'DAPR', 'FMTM', 'MDPR', 'PGTM', 'PRCP', 'SNOW', 'SNWD',
#        'TAVG', 'TMAX', 'TMIN', 'TSUN', 'WDF1', 'WDF2', 'WDF5', 'WDFG', 'WDFM',
#        'WESD', 'WSF1', 'WSF2', 'WSF5', 'WSFG', 'WSFM', 'WT01', 'WT02', 'WT03',
#        'WT04', 'WT05', 'WT07', 'WT08', 'WT09', 'WT10', 'WT11', 'WT13', 'WT14',
#        'WT16', 'WT18', 'WT21', 'WT22', 'WV01', 'WV03', 'WV20'],
#       dtype='object')

# %%
weather_df.shape
# Out:
# (55999, 50)

# %%
weather_df.isnull().sum()
# Out:
# STATION          0
# NAME             0
# LATITUDE         0
# LONGITUDE        0
# ELEVATION        0
# DATE             0
# ACMH         51102
# ACSH         51100
# AWND          8296
# DAPR         55994
# FMTM         29975
# MDPR         55994
# PGTM         27012
# PRCP           395
# SNOW         34329
# SNWD         33523
# TAVG         34391
# TMAX          2341
# TMIN          2345
# TSUN         47204
# WDF1         54202
# WDF2         12594
# WDF5         13680
# WDFG         51233
# WDFM         54910
# WESD         38467
# WSF1         54202
# WSF2         12591
# WSF5         13671
# WSFG         51233
# WSFM         54910
# WT01         40637
# WT02         53504
# WT03         55535
# WT04         55988
# WT05         55618
# WT07         55011
# WT08         40158
# WT09         55829
# WT10         55987
# WT11         55994
# WT13         48722
# WT14         55573
# WT16         52052
# WT18         55991
# WT21         55885
# WT22         55981
# WV01         55926
# WV03         55997
# WV20         55992
# dtype: int64

# %% [markdown]
# ## 2. Handling Missing Values
#
# After exploring the missing values, we calculate the percentage of missing values for each column to identify which columns have more than 50% missing data. Columns with more than 50% missing values are considered unreliable and are dropped to maintain the quality of the dataset.
#
# We proceed by dropping columns that have over 50% missing data.
#
# Once these columns are dropped, we are left with the following important columns for further analysis:
#
# - **`STATION`**
# - **`NAME`**
# - **`LATITUDE`**
# - **`LONGITUDE`**
# - **`ELEVATION`**
# - **`DATE`**
# - **`AWND`**
# - **`PGTM`**
# - **`PRCP`**
# - **`TMAX`**
# - **`TMIN`**
# - **`WDF2`**
# - **`WDF5`**
# - **`WSF2`**
# - **`WSF5`**

# %%
missing_percent = weather_df.isnull().sum() / len(weather_df) * 100
missing_percent.sort_values(ascending=False)
# Out:
# WV03         99.996429
# WT11         99.991071
# MDPR         99.991071
# DAPR         99.991071
# WV20         99.987500
# WT18         99.985714
# WT04         99.980357
# WT10         99.978571
# WT22         99.967857
# WV01         99.869641
# WT21         99.796425
# WT09         99.696423
# WT05         99.319631
# WT14         99.239272
# WT03         99.171414
# WT07         98.235683
# WDFM         98.055322
# WSFM         98.055322
# WSF1         96.791014
# WDF1         96.791014
# WT02         95.544563
# WT16         92.951660
# WDFG         91.489134
# WSFG         91.489134
# ACMH         91.255201
# ACSH         91.251629
# WT13         87.005125
# TSUN         84.294362
# WT01         72.567367
# WT08         71.711995
# WESD         68.692298
# TAVG         61.413597
# SNOW         61.302880
# SNWD         59.863569
# FMTM         53.527742
# PGTM         48.236576
# WDF5         24.429008
# WSF5         24.412936
# WDF2         22.489687
# WSF2         22.484330
# AWND         14.814550
# TMIN          4.187575
# TMAX          4.180432
# PRCP          0.705370
# NAME          0.000000
# DATE          0.000000
# ELEVATION     0.000000
# LONGITUDE     0.000000
# LATITUDE      0.000000
# STATION       0.000000
# dtype: float64

# %%
# Drop columns with more than 50% missing values
threshold = 50
cols_to_drop = missing_percent[missing_percent > threshold].index
weather_df.drop(columns=cols_to_drop, inplace=True)

# %% [markdown]
# ## 3. Imputing Remaining Missing Values
#
# For the remaining columns, we choose to impute missing values using the **median**.
#
# ### Why Impute with Median?
#
# The **median** is a good choice for imputing missing values because it is less sensitive to outliers compared to the mean. Weather data is prone to extreme values (e.g., storms or temperature spikes), which can skew the mean. The median, on the other hand, represents the central tendency of the data without being influenced by extreme values, making it more robust for imputation.
#
# - **Robustness to Outliers**: The median is not influenced by extreme values, so it prevents any skewed data from distorting the imputation process.
# - **Preserving Data Distribution**: Since weather data often contains outliers (e.g., extreme weather events), using the median ensures that the imputed values are more representative of the data’s central tendency.
# - **Maintaining Consistency**: Imputing with the median ensures that the model training process remains consistent without introducing unnecessary bias that might occur with extreme outliers.

# %%
# Optional Fill remaining NaNs with column-wise median
weather_df.fillna(weather_df.median(numeric_only=True), inplace=True)

# %%
weather_df.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND',
#        'PGTM', 'PRCP', 'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5'],
#       dtype='object')

# %% [raw]
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND',
#        'PGTM', 'PRCP', 'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5'],
#       dtype='object')

# %%
weather_df['STATION'].value_counts()
# Out:
# STATION
# USW00093193    10593
# USW00023174    10593
# USW00023188    10593
# USW00003171     8216
# USW00023257     8185
# MXN00021053     5947
# US1CASR0055     1872
# Name: count, dtype: int64

# %%
weather_df['NAME'].value_counts()
# Out:
# NAME
# FRESNO YOSEMITE INTERNATIONAL, CA US        10593
# LOS ANGELES INTERNATIONAL AIRPORT, CA US    10593
# SAN DIEGO INTERNATIONAL AIRPORT, CA US      10593
# RIVERSIDE MUNICIPAL AIRPORT, CA US           8216
# MERCED MUNICIPAL AIRPORT, CA US              8185
# SAN BERNARDINO LAGUNAS, MX                   5947
# SAN BERNARDINO 5.1 NW, CA US                 1872
# Name: count, dtype: int64

# %%
weather_df.isnull().sum()
# Out:
# STATION      0
# NAME         0
# LATITUDE     0
# LONGITUDE    0
# ELEVATION    0
# DATE         0
# AWND         0
# PGTM         0
# PRCP         0
# TMAX         0
# TMIN         0
# WDF2         0
# WDF5         0
# WSF2         0
# WSF5         0
# dtype: int64

# %%
weather_df.head()
# Out:
#        STATION                                  NAME  LATITUDE  LONGITUDE  \
# 0  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
# 1  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
# 2  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
# 3  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
# 4  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
#
#    ELEVATION      DATE  AWND    PGTM  PRCP  TMAX  TMIN   WDF2   WDF5  WSF2  \
# 0      101.9  1/1/1992  3.80  2100.0  0.00  59.0  32.0  270.0  270.0  15.0
# 1      101.9  1/2/1992  4.70   222.0  0.00  46.0  40.0  270.0  270.0  15.0
# 2      101.9  1/3/1992  3.80   523.0  0.07  52.0  41.0  270.0  270.0  15.0
# 3      101.9  1/4/1992  8.72  2309.0  0.00  60.0  43.0  270.0  270.0  15.0
# 4      101.9  1/5/1992  8.50   422.0  1.02  59.0  44.0  270.0  270.0  15.0
#
#    WSF5
# 0  19.0
# 1  19.0
# 2  19.0
# 3  19.0
# 4  19.0

# %%
import pandas as pd
weather_df['DATE'] = pd.to_datetime(weather_df['DATE'])
weather_df['DATE']
# Out:
# 0       1992-01-01
# 1       1992-01-02
# 2       1992-01-03
# 3       1992-01-04
# 4       1992-01-05
#            ...
# 55994   2020-12-27
# 55995   2020-12-28
# 55996   2020-12-29
# 55997   2020-12-30
# 55998   2020-12-31
# Name: DATE, Length: 55999, dtype: datetime64[ns]

# %%
weather_df.head()
# Out:
#        STATION                                  NAME  LATITUDE  LONGITUDE  \
# 0  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
# 1  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
# 2  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
# 3  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
# 4  USW00093193  FRESNO YOSEMITE INTERNATIONAL, CA US  36.77999 -119.72016
#
#    ELEVATION       DATE  AWND    PGTM  PRCP  TMAX  TMIN   WDF2   WDF5  WSF2  \
# 0      101.9 1992-01-01  3.80  2100.0  0.00  59.0  32.0  270.0  270.0  15.0
# 1      101.9 1992-01-02  4.70   222.0  0.00  46.0  40.0  270.0  270.0  15.0
# 2      101.9 1992-01-03  3.80   523.0  0.07  52.0  41.0  270.0  270.0  15.0
# 3      101.9 1992-01-04  8.72  2309.0  0.00  60.0  43.0  270.0  270.0  15.0
# 4      101.9 1992-01-05  8.50   422.0  1.02  59.0  44.0  270.0  270.0  15.0
#
#    WSF5
# 0  19.0
# 1  19.0
# 2  19.0
# 3  19.0
# 4  19.0

# %% [markdown]
# ## 4. Data Cleaning Summary
#
# After handling missing values by:
# 1. Dropping columns with more than 50% missing data.
# 2. Imputing the remaining missing values with the median.
#
# We are left with a cleaner, more reliable dataset containing the following columns:
#
# - **`STATION`**: Station identifier.
# - **`NAME`**: Name of the station.
# - **`LATITUDE`**: Latitude of the station.
# - **`LONGITUDE`**: Longitude of the station.
# - **`ELEVATION`**: Elevation of the station.
# - **`DATE`**: The date of the observation.
# - **`AWND`**: Average wind speed.
# - **`PGTM`**: Peak gust time.
# - **`PRCP`**: Precipitation.
# - **`TMAX`**: Maximum temperature.
# - **`TMIN`**: Minimum temperature.
# - **`WDF2`**: Wind direction (2-minute average).
# - **`WDF5`**: Wind direction (5-second maximum).
# - **`WSF2`**: Wind speed (2-minute average).
# - **`WSF5`**: Wind speed (5-second maximum).
#
# This cleaned dataset is now ready for further exploration and modeling for **wildfire prediction**.

# %%
# Save the CAL_FIRE dataframe to a CSV file
weather_df.to_csv('Weather_Database.csv', index=False)

# %% [markdown]
# ## 🌲 NOAA Weather Data Columns: Full Forms & Wildfire Relevance
#
# ### 🛰️ Station Metadata
# - **STATION**: Unique identifier for the weather station.
# - **NAME**: Name of the station (helps geolocate the readings).
# - **LATITUDE** / **LONGITUDE**: Coordinates of the weather station — crucial for mapping to fire locations.
# - **ELEVATION**: Station elevation above sea level (in meters) — impacts temperature, wind, and precipitation.
#
# These help in **spatial matching** with California wildfire locations (e.g., FRAP dataset).
#
# ---
#
# ### 📅 Temporal Data
# - **DATE**: The observation date (YYYY-MM-DD) — used to align weather conditions with wildfire start dates.
#
# ---
#
# ### 🌬️ Wind Features
# - **AWND**: *Average Daily Wind Speed* (in meters per second)
#   ⏩ High wind speeds increase wildfire spread potential and direction.
#
# - **WDF2** / **WDF5**: *Direction of Fastest 2-minute / 5-second Wind*
#   ⏩ Indicates wind direction before and during peak gusts — important for modeling spread direction.
#
# - **WSF2** / **WSF5**: *Fastest 2-minute / 5-second Wind Speed*
#   ⏩ Sudden wind gusts can ignite or rapidly expand fires — useful for early risk detection.
#
# ---
#
# ### 🌧️ Precipitation & Soil Moisture
# - **PRCP**: *Daily Precipitation* (in tenths of mm)
#   ⏩ Less rainfall = drier vegetation → higher fire risk.
#
# - **PGTM**: *Peak Gust Time*
#   ⏩ When the peak wind gust occurred. Combined with wind speed and fire start times, it can reveal ignition patterns.
#
# ---
#
# ### 🌡️ Temperature
# - **TMAX**: *Maximum Daily Temperature* (tenths of °C)
#   ⏩ Hot days dry out fuel sources faster, increasing risk.
#
# - **TMIN**: *Minimum Daily Temperature* (tenths of °C)
#   ⏩ Helps understand diurnal variation; low nighttime temps slow spread, but warm nights can maintain combustion.
#
# ---
#
# ## 🔥 Summary: Why These Features Matter for Wildfires
#
# These variables represent **key fire-driving weather patterns**:
# - Wind (spread and direction)
# - Temperature (fuel ignition and drying)
# - Precipitation (fuel moisture)
# - Location + Time (to align with fire incidents)
#
# When merged with the **California FRAP wildfire dataset**, they can help **build predictive models**, **assess fire risk**, or **analyze historical trends**.
#
# ---
#
# ### 🚀 Data Cleaning & Readiness
#
# The dataset has been **cleaned** by addressing missing values, imputing with the median, and dropping columns with more than 50% missing data. It is now **ready to be merged** with other relevant datasets, like the **California FRAP wildfire dataset**, for further analysis, prediction, and model building for wildfire cause prediction and risk assessment.

# %%
noaa_df = pd.read_csv("C:\\Users\\annis\\Project dsc 550\\Weather_Database.csv")

# %%
noaa_df.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND',
#        'PGTM', 'PRCP', 'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5'],
#       dtype='object')

# %%
# Generate summary statistics for numerical columns
numerical_summary = noaa_df.describe()

# Count missing values for all columns
missing_values = noaa_df.isnull().sum()

# Split columns into numerical and categorical
numerical_columns = noaa_df.select_dtypes(include=['float64', 'int64']).columns
categorical_columns = noaa_df.select_dtypes(include=['object']).columns

# Display summary statistics and missing values
print("=== Numerical Columns Summary ===")
print(numerical_summary)
print("\n=== Missing Values Count ===")
print(missing_values)
print("\n=== Categorical Columns ===")
print(categorical_columns)
# Out:
# === Numerical Columns Summary ===
#           LATITUDE     LONGITUDE     ELEVATION          AWND          PGTM  \
# count  55999.00000  55999.000000  55999.000000  55999.000000  55999.000000
# mean      33.11905   -116.305593    267.830179      6.057037   1454.550046
# std        5.26842      6.669558    504.151440      2.417765    310.194704
# min       18.60000   -120.517880      4.600000      0.000000      0.000000
# 25%       32.73360   -119.720160     29.700000      4.700000   1449.000000
# 50%       33.95282   -118.386600     46.500000      5.820000   1455.000000
# 75%       36.77999   -117.183100    257.700000      7.160000   1501.000000
# max       37.28597    -97.266700   1692.900000     23.940000   2359.000000
#
#                PRCP          TMAX          TMIN          WDF2          WDF5  \
# count  55999.000000  55999.000000  55999.000000  55999.000000  55999.000000
# mean       0.035001     74.183646     52.840765    260.286612    258.936017
# std        0.161488     12.231321      9.999122     64.181458     65.392087
# min        0.000000     34.000000      0.000000      0.000000      0.000000
# 25%        0.000000     66.000000     46.000000    260.000000    260.000000
# 50%        0.000000     72.000000     53.000000    270.000000    270.000000
# 75%        0.000000     80.000000     61.000000    300.000000    290.000000
# max        4.800000    118.000000     90.000000    360.000000    360.000000
#
#                WSF2          WSF5
# count  55999.000000  55999.000000
# mean      15.669105     19.616481
# std       18.614000      7.455681
# min        0.000000      0.000000
# 25%       13.000000     17.000000
# 50%       15.000000     19.000000
# 75%       16.100000     21.000000
# max      916.900000    293.000000
#
# === Missing Values Count ===
# STATION      0
# NAME         0
# LATITUDE     0
# LONGITUDE    0
# ELEVATION    0
# DATE         0
# AWND         0
# PGTM         0
# PRCP         0
# TMAX         0
# TMIN         0
# WDF2         0
# WDF5         0
# WSF2         0
# WSF5         0
# dtype: int64
#
# === Categorical Columns ===
# Index(['STATION', 'NAME', 'DATE'], dtype='object')

# %%
noaa_df.describe()
# Out:
#           LATITUDE     LONGITUDE     ELEVATION          AWND          PGTM  \
# count  55999.00000  55999.000000  55999.000000  55999.000000  55999.000000
# mean      33.11905   -116.305593    267.830179      6.057037   1454.550046
# std        5.26842      6.669558    504.151440      2.417765    310.194704
# min       18.60000   -120.517880      4.600000      0.000000      0.000000
# 25%       32.73360   -119.720160     29.700000      4.700000   1449.000000
# 50%       33.95282   -118.386600     46.500000      5.820000   1455.000000
# 75%       36.77999   -117.183100    257.700000      7.160000   1501.000000
# max       37.28597    -97.266700   1692.900000     23.940000   2359.000000
#
#                PRCP          TMAX          TMIN          WDF2          WDF5  \
# count  55999.000000  55999.000000  55999.000000  55999.000000  55999.000000
# mean       0.035001     74.183646     52.840765    260.286612    258.936017
# std        0.161488     12.231321      9.999122     64.181458     65.392087
# min        0.000000     34.000000      0.000000      0.000000      0.000000
# 25%        0.000000     66.000000     46.000000    260.000000    260.000000
# 50%        0.000000     72.000000     53.000000    270.000000    270.000000
# 75%        0.000000     80.000000     61.000000    300.000000    290.000000
# max        4.800000    118.000000     90.000000    360.000000    360.000000
#
#                WSF2          WSF5
# count  55999.000000  55999.000000
# mean      15.669105     19.616481
# std       18.614000      7.455681
# min        0.000000      0.000000
# 25%       13.000000     17.000000
# 50%       15.000000     19.000000
# 75%       16.100000     21.000000
# max      916.900000    293.000000

# %% [markdown]
# ### Summary of NOAA Weather Dataset
#
# #### 1. **Numerical Columns Summary**
#
# The numerical columns in the NOAA dataset include weather-related measurements such as **LATITUDE**, **LONGITUDE**, **ELEVATION**, **AWND** (Average Wind Speed), **PGTM** (Peak Gust Time), **PRCP** (Precipitation), **TMAX** (Maximum Temperature), **TMIN** (Minimum Temperature), **WDF2** (Wind Direction at 2 meters), **WDF5** (Wind Direction at 5 meters), **WSF2** (Wind Speed at 2 meters), and **WSF5** (Wind Speed at 5 meters).
#
# The following statistical summary provides insights into the range, mean, and distribution of these columns:
#
# - **LATITUDE** and **LONGITUDE** range from **18.6 to 37.3** and **-120.5 to -97.2** respectively, with mean values around **33.12** and **-116.31**, indicating that the data covers a broad geographical area.
# - **ELEVATION** has a large spread from **4.6** to **1692.9 meters**, with a mean of **267.83 meters**, implying varying altitudes.
# - **AWND** (Average Wind Speed) has a mean of **6.06 m/s**, with a max value of **23.94 m/s**.
# - **PGTM** (Peak Gust Time) ranges from **0** to **2359** with a mean of **1454.55**, reflecting peak gust timings.
# - **PRCP** (Precipitation) has values ranging from **0** to **4.8** inches, with an average of **0.035 inches**.
# - **TMAX** (Maximum Temperature) has values between **34** and **118°F**, with an average of **74.18°F**.
# - **TMIN** (Minimum Temperature) ranges from **0** to **90°F**, with a mean of **52.84°F**.
# - **WDF2** and **WDF5** (Wind Direction at 2 meters and 5 meters) vary from **0 to 360 degrees** with an average around **260** degrees.
# - **WSF2** (Wind Speed at 2 meters) and **WSF5** (Wind Speed at 5 meters) range from **0 to 916.9 m/s** and **0 to 293 m/s** respectively, with average values of **15.67 m/s** and **19.62 m/s**.
#
# #### 2. **Missing Values**
#
# There are no missing values in any column in this dataset. All 55,999 entries are complete across all variables.
#
# #### 3. **Categorical Columns**
#
# The dataset contains the following categorical columns:
# - **STATION**: This likely refers to the weather station ID or name where the data was recorded.
# - **NAME**: Possibly the name of the location or station.
# - **DATE**: The date when the observation was recorded.
#
# These columns hold discrete values that may categorize or identify individual weather stations and their recorded dates.
#
# ---
#
# ### Conclusion
#
# This dataset is clean, with no missing values, and provides comprehensive weather data across various stations and time points. The numerical columns provide detailed insights into geographical, wind, temperature, and precipitation characteristics, which could be useful for modeling and analysis related to weather patterns and their impact on wildfires or other phenomena.

# %% [markdown]
# Date Handling: Convert DATE to DateTime format and extract useful time-based features (year, month).
#
# Wind Variables: Normalize or transform wind speed and direction.
#
# Handle Outliers: Identify and cap extreme values (e.g., for wind speed or elevation).
#
# Encoding: Label or One-Hot encode categorical features (e.g., STATION, NAME).
#
# Feature Scaling: Standardize or normalize numerical features if using machine learning models.
#
# Feature Engineering: Create interaction terms (e.g., temp_range) or binned variables (e.g., AWND_binned).
#
# Time Series Features: Add seasonal features or date-related variables (e.g., season based on the month).

# %% [markdown]
# ## Data Visualization:

# %% [markdown]
# ## Temperature Distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting distribution of TMAX and TMIN
plt.figure(figsize=(10, 6))
sns.histplot(noaa_df['TMAX'], kde=True, color='orange', label='TMAX', stat='density')
sns.histplot(noaa_df['TMIN'], kde=True, color='blue', label='TMIN', stat='density')
plt.title('Distribution of Maximum and Minimum Temperatures')
plt.xlabel('Temperature (°F)')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# ## Wind Speed and Direction

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=noaa_df, x='WDF2', y='WSF2', alpha=0.5, color='purple')
plt.title('Wind Speed vs Wind Direction (WDF2 vs WSF2)')
plt.xlabel('Wind Direction (°)')
plt.ylabel('Wind Speed (mph)')
plt.show()

# %% [markdown]
# ## Temperature vs. WindSpeed

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=noaa_df, x='TMIN', y='WSF2', alpha=0.6)
plt.title('Max Temperature vs Wind Speed')
plt.xlabel('Max Temperature (°F)')
plt.ylabel('Wind Speed (mph)')
plt.show()

# %% [markdown]
# ## Wind Speed by Station

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=noaa_df, x='STATION', y='WSF2')
plt.title('Wind Speed Distribution by Station')
plt.xlabel('Station')
plt.ylabel('Wind Speed (mph)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Correlation Heat Map

# %%
# Compute the correlation matrix
corr_matrix = noaa_df[['LATITUDE', 'LONGITUDE', 'ELEVATION', 'AWND', 'PGTM', 'PRCP', 'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5']].corr()

# Plotting the correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %%
print(corr_matrix)
# Out:
#            LATITUDE  LONGITUDE  ELEVATION      AWND      PGTM      PRCP  \
# LATITUDE   1.000000  -0.988133  -0.924906  0.025998  0.016339 -0.095189
# LONGITUDE -0.988133   1.000000   0.967995 -0.042512 -0.007587  0.099058
# ELEVATION -0.924906   0.967995   1.000000 -0.070531  0.007087  0.101316
# AWND       0.025998  -0.042512  -0.070531  1.000000  0.016106  0.152311
# PGTM       0.016339  -0.007587   0.007087  0.016106  1.000000 -0.039118
# PRCP      -0.095189   0.099058   0.101316  0.152311 -0.039118  1.000000
# TMAX       0.121892  -0.091226  -0.039526  0.048318  0.128454 -0.179834
# TMIN       0.267058  -0.320241  -0.380907  0.288397  0.067868 -0.085629
# WDF2      -0.025063   0.034847   0.038717  0.070997  0.092534 -0.123077
# WDF5      -0.043808   0.048351   0.047256  0.073157  0.118950 -0.113843
# WSF2      -0.001605  -0.006826  -0.016021  0.179928  0.000181  0.032469
# WSF5       0.030598  -0.032434  -0.023976  0.463077 -0.052145  0.112378
#
#                TMAX      TMIN      WDF2      WDF5      WSF2      WSF5
# LATITUDE   0.121892  0.267058 -0.025063 -0.043808 -0.001605  0.030598
# LONGITUDE -0.091226 -0.320241  0.034847  0.048351 -0.006826 -0.032434
# ELEVATION -0.039526 -0.380907  0.038717  0.047256 -0.016021 -0.023976
# AWND       0.048318  0.288397  0.070997  0.073157  0.179928  0.463077
# PGTM       0.128454  0.067868  0.092534  0.118950  0.000181 -0.052145
# PRCP      -0.179834 -0.085629 -0.123077 -0.113843  0.032469  0.112378
# TMAX       1.000000  0.612273  0.268773  0.231659  0.011373  0.072429
# TMIN       0.612273  1.000000  0.179154  0.159609  0.065774  0.098763
# WDF2       0.268773  0.179154  1.000000  0.710272 -0.095808 -0.004839
# WDF5       0.231659  0.159609  0.710272  1.000000  0.015611 -0.013115
# WSF2       0.011373  0.065774 -0.095808  0.015611  1.000000  0.154816
# WSF5       0.072429  0.098763 -0.004839 -0.013115  0.154816  1.000000

# %% [markdown]
# ### Correlation Matrix Explanation
#
# The correlation matrix below represents the pairwise correlations between different variables in the dataset. The values range from -1 to 1, where:
#
# - `1` indicates a perfect positive correlation,
# - `-1` indicates a perfect negative correlation,
# - `0` indicates no correlation.
#
# #### Key Observations:
# 1. **LATITUDE and LONGITUDE**: These two features have a very strong negative correlation of `-0.988133`, which means they are inversely related.
# 2. **LATITUDE and ELEVATION**: There is a strong negative correlation of `-0.924906`, indicating that as the latitude increases, elevation tends to decrease.
# 3. **AWND (Average Wind Speed) and WSF5 (Wind Speed at 5ft)**: These two variables show a strong positive correlation of `0.463077`, suggesting that as one increases, the other is likely to increase as well.
# 4. **PRCP (Precipitation) and WSF2 (Wind Speed at 2ft)**: There is a weak positive correlation of `0.032469`, meaning there is a small relationship between precipitation and wind speed at 2ft.
# 5. **TMAX (Max Temperature) and TMIN (Min Temperature)**: These variables have a strong positive correlation of `0.612273`, meaning that higher minimum temperatures tend to correspond with higher maximum temperatures.
# 6. **WDF2 (Wind Direction at 2ft) and WDF5 (Wind Direction at 5ft)**: These features have a strong positive correlation of `0.710272`, suggesting that wind direction at 2ft and 5ft are closely related.
# 7. **WSF5 and WSF2**: The correlation between wind speed at 5ft and wind speed at 2ft is moderate at `0.154816`, indicating some relationship between them.
#
# #### Other Key Relationships:
# - **TMAX** has a weak positive correlation with **WSF5 (0.072429)**, suggesting that higher temperatures are somewhat related to wind speed at 5ft.
# - **ELEVATION** shows a negative correlation with **TMAX (-0.039526)**, but it is very weak, implying that elevation does not strongly influence the maximum temperature.
# - **PRCP** has weak negative correlations with **TMAX (-0.179834)** and **TMIN (-0.085629)**, suggesting that higher precipitation might slightly lower temperatures.
#
# #### Summary:
# - Strong correlations exist between geographic features (like LATITUDE, LONGITUDE, and ELEVATION).
# - Temperature and wind speed features show weaker correlations with other environmental factors.
# - The highest correlation is between wind direction at 2ft and 5ft, indicating consistency in wind direction at different altitudes.

# %% [markdown]
# ### FRAP Features
# | Feature                       | Description                                        |
# |-------------------------------|----------------------------------------------------|
# | `DISCOVERY_DATE`               | The date the fire was discovered                   |
# | `DISCOVERY_TIME`               | The time the fire was discovered                   |
# | `FIRE_YEAR`                    | Year of the fire incident                          |
# | `LATITUDE`                     | Latitude of the fire incident                      |
# | `LONGITUDE`                    | Longitude of the fire incident                     |
# | `STATE`                        | State where the fire occurred                      |
# | `FIRE_SIZE`                    | Size of the fire (in acres)                        |
# | `FIRE_SIZE_CLASS`              | Categorized class of fire size (e.g., small, large)|
# | `NWCG_CAUSE_CLASSIFICATION`    | Classification of the fire cause (human/natural)   |
# | `NWCG_GENERAL_CAUSE`           | More specific cause of the fire                   |
# | `COUNTY`                       | Name of the county where the fire occurred        |
#
# ### NOAA Features
# | Feature                       | Description                                        |
# |-------------------------------|----------------------------------------------------|
# | `STATION`                      | Weather station identifier                         |
# | `NAME`                         | Name of the weather station                        |
# | `LATITUDE`                     | Latitude of the weather station                    |
# | `LONGITUDE`                    | Longitude of the weather station                   |
# | `ELEVATION`                    | Elevation of the weather station                   |
# | `DATE`                         | Date of the weather observation                    |
# | `AWND`                         | Average wind speed (2-minute average)              |
# | `PGTM`                         | Peak gust wind speed                               |
# | `PRCP`                         | Precipitation (in inches)                          |
# | `TMAX`                         | Maximum temperature (in Fahrenheit)                |
# | `TMIN`                         | Minimum temperature (in Fahrenheit)                |
# | `WDF2`                         | Wind direction at 2 meters (degrees)               |
# | `WDF5`                         | Wind direction at 5 meters (degrees)               |
# | `WSF2`                         | Wind speed at 2 meters (mph)                       |
# | `WSF5`                         | Wind speed at 5 meters (mph)                       |
